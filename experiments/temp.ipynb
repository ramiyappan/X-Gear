> <--Place--> [None] </--Place--> <--Adjudicator--> [None] </--Adjudicator-->",
#   "Anwar will be taken to the appeal court early Friday for a bail application pending his appeal to the country 's highest Federal Court againt his sodomy conviction , counsel Sankara Nair said . <--triggerword--> appeal <--template--> <--Plaintiff--> [None] </--Plaintiff--> <--Place--> [None] </--Place--> <--Adjudicator--> [None] </--Adjudicator-->",
#   "Anwar will be taken to the appeal court early Friday for a bail application pending his appeal to the country 's highest Federal Court againt his sodomy conviction , counsel Sankara Nair said . <--triggerword--> conviction <--template--> <--Defendant--> [None] </--Defendant--> <--Place--> [None] </--Place--> <--Adjudicator--> [None] </--Adjudicator-->",
#   'Prison authorities have given the nod for Anwar to be taken home later in the afternoon to marry his eldest daughter , Nurul Izzah , to engineer Raja Ahmad Sharir Iskandar in a traditional Malay ceremony , he said . <--triggerword--> taken <--template--> <--Artifact--> [None] </--Artifact--> <--Destination--> [None] </--Destination--> <--Origin--> [None] </--Origin--> <--Vehicle--> [None] </--Vehicle--> <--Agent--> [None] </--Agent--> <--Place--> [None] </--Place-->',
# ...
#    'tokens': ['In',
#     'a',
#     'letter',
#     'to',
#     'U.N.',
#     'Secretary',
#     '-',
#     'General',
#     'Kofi',
#     'Annan',
#     ',',
#     'Ramadan',
#     'said',
#     ',',
#     '``',
#     'It',
#     'is',
#     'also',
#     'regrettable',
#     'and',
#     'deplorable',
#     'that',
#     'the',
#     '(',
#     'U.N.',
#     ')',
#     'General',
#     'Secretariat',
#     'has',
#     'not',
#     'issued',
#     'any',
#     'statement',
#     'or',
#     'reaction',
#     'that',
#     'condemns',
#     'or',
#     'deplores',
#     'this',
#     'aggression',
#     '.',
#     "''"]},
#   {'trigger text': 'bombing',
#    'trigger span': (3, 4),
#    'event type': 'Conflict:Attack',
#    'arguments': {'Target': [{'argument text': 'installations',
#       'argument span': (16, 17)}]},
#    'passage': 'Despite the heavy bombing , which the U.S. Central Command said targeted military command and control installations , the Iraqi regime gave no sign of quitting .',
#    'tokens': ['Despite',
#     'the',
#     'heavy',
#     'bombing',
#     ',',
#     'which',
#     'the',
#     'U.S.',
#     'Central',
#     'Command',
#     'said',
#     'targeted',
#     'military',
#     'command',
#     'and',
#     'control',
#     'installations',
#     ',',
#     'the',
#     'Iraqi',
#     'regime',
#     'gave',
#     'no',
#     'sign',
#     'of',
#     'quitting',
#     '.']},
#   {'trigger text': 'hit',
#    'trigger span': (3, 4),
#    'event type': 'Conflict:Attack',
#    'arguments': {'Instrument': [{'argument text': 'Bombers',
#       'argument span': (0, 1)}],
#     'Place': [{'argument text': 'cities', 'argument span': (8, 9)},
#      {'argument text': 'Mosul', 'argument span': (10, 11)},
#      {'argument text': 'Kirkuk', 'argument span': (12, 13)},
#      {'argument text': 'Tikrit', 'argument span': (14, 15)}]},
#    'passage': "Bombers have also hit targets in the northern cities of Mosul , Kirkuk and Tikrit , Saddam 's hometown .",
#    'tokens': ['Bombers',
#     'have',
#     'also',
#     'hit',
#     'targets',
#     'in',
#     'the',
#     'northern',
#     'cities',
#     'of',
#     'Mosul',
#     ',',
#     'Kirkuk',
#     'and',
#     'Tikrit',
#     ',',
#     'Saddam',
#     "'s",
#     'hometown',
#     '.']},
#   {'trigger text': 'meeting',
#    'trigger span': (12, 13),
#    'event type': 'Contact:Meet',
#    'arguments': {'Entity': [{'argument text': 'commander',
#       'argument span': (19, 20)},
#      {'argument text': 'minister', 'argument span': (28, 29)}]},
#    'passage': 'The Iraqi government released a video of Saddam , in uniform , meeting with his son Qusai , the commander of the Republican Guard , and the defense minister , Gen. Sultan Hashim Ahmad .',
#    'tokens': ['The',
#     'Iraqi',
#     'government',
#     'released',
#     'a',
#     'video',
#     'of',
#     'Saddam',
#     ',',
#     'in',
#     'uniform',
#     ',',
#     'meeting',
#     'with',
#     'his',
#     'son',
#     'Qusai',
#     ',',
#     'the',
#     'commander',
#     'of',
#     'the',
#     'Republican',
#     'Guard',
#     ',',
#     'and',
#     'the',
#     'defense',
#     'minister',
#     ',',
#     'Gen.',
#     'Sultan',
#     'Hashim',
#     'Ahmad',
#     '.']},
#   {'trigger text': 'vacation',
#    'trigger span': (19, 20),
#    'event type': 'Movement:Transport',
#    'arguments': {'Artifact': [{'argument text': 'premier',
#       'argument span': (1, 2)}],
#     'Destination': [{'argument text': 'Hawaiian', 'argument span': (18, 19)}]},
#    'passage': 'The premier of the western Canadian province of British Columbia pleaded no contest to driving drunk during a Hawaiian vacation in January .',
#    'tokens': ['The',
#     'premier',
#     'of',
#     'the',
#     'western',
#     'Canadian',
#     'province',
#     'of',
#     'British',
#     'Columbia',
#     'pleaded',
#     'no',
#     'contest',
#     'to',
#     'driving',
#     'drunk',
#     'during',
#     'a',
#     'Hawaiian',
#     'vacation',
#     'in',
#     'January',
#     '.']},
#   {'trigger text': 'fines',
#    'trigger span': (6, 7),
#    'event type': 'Justice:Fine',
#    'arguments': {'Entity': [{'argument text': 'Gordon Campbell',
#       'argument span': (0, 2)}]},
#    'passage': 'Gordon Campbell was ordered to pay fines and fees totaling $ 913 , complete a 14-hour alcohol assessment program and have a substance abuse assessment .',
#    'tokens': ['Gordon',
#     'Campbell',
#     'was',
#     'ordered',
#     'to',
#     'pay',
#     'fines',
#     'and',
#     'fees',
#     'totaling',
#     '$',
#     '913',
#     ',',
#     'complete',
#     'a',
#     '14-hour',
#     'alcohol',
#     'assessment',
#     'program',
#     'and',
#     'have',
#     'a',
#     'substance',
#     'abuse',
#     'assessment',
#     '.']},
#   {'trigger text': 'fines',
#    'trigger span': (10, 11),
#    'event type': 'Justice:Fine',
#    'arguments': {'Entity': [{'argument text': 'Campbell',
#       'argument span': (6, 7)}]},
#    'passage': 'He also brought a check from Campbell to pay the fines and fees .',
#    'tokens': ['He',
#     'also',
#     'brought',
#     'a',
#     'check',
#     'from',
#     'Campbell',
#     'to',
#     'pay',
#     'the',
#     'fines',
#     'and',
#     'fees',
#     '.']},
#   {'trigger text': 'returning',
#    'trigger span': (6, 7),
#    'event type': 'Movement:Transport',
#    'arguments': {'Destination': [{'argument text': 'Vancouver',
#       'argument span': (8, 9)}],
#     'Artifact': [{'argument text': 'Campbell', 'argument span': (13, 14)}]},
#    'passage': 'In a tearful news conference after returning to Vancouver two days later , Campbell apologized to British Columbians , but refused to resign as premier .',
#    'tokens': ['In',
#     'a',
#     'tearful',
#     'news',
#     'conference',
#     'after',
#     'returning',
#     'to',
#     'Vancouver',
#     'two',
#     'days',
#     'later',
#     ',',
#     'Campbell',
#     'apologized',
#     'to',
#     'British',
#     'Columbians',
#     ',',
#     'but',
#     'refused',
#     'to',
#     'resign',
#     'as',
#     'premier',
#     '.']},
#   {'trigger text': 'resign',
#    'trigger span': (22, 23),
#    'event type': 'Personnel:End-Position',
#    'arguments': {'Place': [{'argument text': 'Vancouver',
#       'argument span': (8, 9)}],
#     'Person': [{'argument text': 'Campbell', 'argument span': (13, 14)}],
#     'Entity': [{'argument text': 'British Columbians',
#       'argument span': (16, 18)}]},
#    'passage': 'In a tearful news conference after returning to Vancouver two days later , Campbell apologized to British Columbians , but refused to resign as premier .',
#    'tokens': ['In',
#     'a',
#     'tearful',
#     'news',
#     'conference',
#     'after',
#     'returning',
#     'to',
#     'Vancouver',
#     'two',
#     'days',
#     'later',
#     ',',
#     'Campbell',
#     'apologized',
#     'to',
#     'British',
#     'Columbians',
#     ',',
#     'but',
#     'refused',
#     'to',
#     'resign',
#     'as',
#     'premier',
#     '.']},
#   {'trigger text': 'Retired',
#    'trigger span': (0, 1),
#    'event type': 'Personnel:End-Position',
#    'arguments': {'Entity': [{'argument text': 'General Electric Co.',
#       'argument span': (1, 4)}],
#     'Person': [{'argument text': 'Jack Welch', 'argument span': (5, 7)}]},
#    'passage': 'Retired General Electric Co. Chairman Jack Welch is seeking work - related documents of his estranged wife in his high - stakes divorce case .',
#    'tokens': ['Retired',
#     'General',
#     'Electric',
#     'Co.',
#     'Chairman',
#     'Jack',
#     'Welch',
#     'is',
#     'seeking',
#     'work',
#     '-',
#     'related',
#     'documents',
#     'of',
#     'his',
#     'estranged',
#     'wife',
#     'in',
#     'his',
#     'high',
#     '-',
#     'stakes',
#     'divorce',
#     'case',
#     '.']},
#   {'trigger text': 'divorce',
#    'trigger span': (22, 23),
#    'event type': 'Life:Divorce',
#    'arguments': {'Person': [{'argument text': 'wife',
#       'argument span': (16, 17)}]},
#    'passage': 'Retired General Electric Co. Chairman Jack Welch is seeking work - related documents of his estranged wife in his high - stakes divorce case .',
#    'tokens': ['Retired',
#     'General',
#     'Electric',
#     'Co.',
#     'Chairman',
#     'Jack',
#     'Welch',
#     'is',
#     'seeking',
#     'work',
#     '-',
#     'related',
#     'documents',
#     'of',
#     'his',
#     'estranged',
#     'wife',
#     'in',
#     'his',
#     'high',
#     '-',
#     'stakes',
#     'divorce',
#     'case',
#     '.']},
#   {'trigger text': 'divorce',
#    'trigger span': (6, 7),
#    'event type': 'Life:Divorce',
#    'arguments': {'Person': [{'argument text': 'Welches',
#       'argument span': (1, 2)}]},
#    'passage': 'The Welches disclosed their plans to divorce a year ago , shortly after Suzy Wetlaufer _ then editor of the Harvard Business Review _ revealed she had become romantically involved with Welch while working on a story about him .',
#    'tokens': ['The',
#     'Welches',
#     'disclosed',
#     'their',
#     'plans',
#     'to',
#     'divorce',
#     'a',
#     'year',
#     'ago',
#     ',',
#     'shortly',
#     'after',
#     'Suzy',
#     'Wetlaufer',
#     '_',
#     'then',
#     'editor',
#     'of',
#     'the',
#     'Harvard',
#     'Business',
#     'Review',
#     '_',
#     'revealed',
#     'she',
#     'had',
#     'become',
#     'romantically',
#     'involved',
#     'with',
#     'Welch',
#     'while',
#     'working',
#     'on',
#     'a',
#     'story',
#     'about',
#     'him',
#     '.']},
#   {'trigger text': 'married',
#    'trigger span': (32, 33),
#    'event type': 'Life:Marry',
#    'arguments': {'Person': [{'argument text': 'Welch',
#       'argument span': (33, 34)}]},
#    'passage': "He also wants to subpoena all documents maintained in Jane Beasley Welch 's personnel file by Shearman & amp ; Sterling , a prestigious corporate law firm where she worked before she married Welch .",
#    'tokens': ['He',
#     'also',
#     'wants',
#     'to',
#     'subpoena',
#     'all',
#     'documents',
#     'maintained',
#     'in',
#     'Jane',
#     'Beasley',
#     'Welch',
#     "'s",
#     'personnel',
#     'file',
#     'by',
#     'Shearman',
#     '&',
#     'amp',
#     ';',
#     'Sterling',
#     ',',
#     'a',
#     'prestigious',
#     'corporate',
#     'law',
#     'firm',
#     'where',
#     'she',
#     'worked',
#     'before',
#     'she',
#     'married',
#     'Welch',
#     '.']},
#   {'trigger text': 'correspondence',
#    'trigger span': (7, 8),
#    'event type': 'Contact:Phone-Write',
#    'arguments': {'Entity': [{'argument text': 'wife',
#       'argument span': (11, 12)},
#      {'argument text': 'partners', 'argument span': (13, 14)}],
#     'Place': [{'argument text': 'office', 'argument span': (22, 23)}]},
#    'passage': "Welch specifically is seeking performance evaluations , correspondence between his estranged wife and partners while she worked at the law firm 's office in London , and documents related to her prospects of becoming a partner .",
#    'tokens': ['Welch',
#     'specifically',
#     'is',
#     'seeking',
#     'performance',
#     'evaluations',
#     ',',
#     'correspondence',
#     'between',
#     'his',
#     'estranged',
#     'wife',
#     'and',
#     'partners',
#     'while',
#     'she',
#     'worked',
#     'at',
#     'the',
#     'law',
#     'firm',
#     "'s",
#     'office',
#     'in',
#     'London',
#     ',',
#     'and',
#     'documents',
#     'related',
#     'to',
#     'her',
#     'prospects',
#     'of',
#     'becoming',
#     'a',
#     'partner',
#     '.']},
#   {'trigger text': 'becoming',
#    'trigger span': (33, 34),
#    'event type': 'Personnel:Start-Position',
#    'arguments': {'Entity': [{'argument text': 'firm',
#       'argument span': (20, 21)}]},
#    'passage': "Welch specifically is seeking performance evaluations , correspondence between his estranged wife and partners while she worked at the law firm 's office in London , and documents related to her prospects of becoming a partner .",
#    'tokens': ['Welch',
#     'specifically',
#     'is',
#     'seeking',
#     'performance',
#     'evaluations',
#     ',',
#     'correspondence',
#     'between',
#     'his',
#     'estranged',
#     'wife',
#     'and',
#     'partners',
#     'while',
#     'she',
#     'worked',
#     'at',
#     'the',
#     'law',
#     'firm',
#     "'s",
#     'office',
#     'in',
#     'London',
#     ',',
#     'and',
#     'documents',
#     'related',
#     'to',
#     'her',
#     'prospects',
#     'of',
#     'becoming',
#     'a',
#     'partner',
#     '.']},
#   {'trigger text': 'retirement',
#    'trigger span': (13, 14),
#    'event type': 'Personnel:End-Position',
#    'arguments': {'Person': [{'argument text': 'Jane Beasley Welch',
#       'argument span': (5, 8)}]},
#    'passage': "Welch also wants details on Jane Beasley Welch 's salary , benefits , retirement plan and other compensation paid to her .",
#    'tokens': ['Welch',
#     'also',
#     'wants',
#     'details',
#     'on',
#     'Jane',
#     'Beasley',
#     'Welch',
#     "'s",
#     'salary',
#     ',',
#     'benefits',
#     ',',
#     'retirement',
#     'plan',
#     'and',
#     'other',
#     'compensation',
#     'paid',
#     'to',
#     'her',
#     '.']},
#   {'trigger text': 'paid',
#    'trigger span': (18, 19),
#    'event type': 'Transaction:Transfer-Money',
#    'arguments': {'Recipient': [{'argument text': 'Jane Beasley Welch',
#       'argument span': (5, 8)}]},
#    'passage': "Welch also wants details on Jane Beasley Welch 's salary , benefits , retirement plan and other compensation paid to her .",
#    'tokens': ['Welch',
#     'also',
#     'wants',
#     'details',
#     'on',
#     'Jane',
#     'Beasley',
#     'Welch',
#     "'s",
#     'salary',
#     ',',
#     'benefits',
#     ',',
#     'retirement',
#     'plan',
#     'and',
#     'other',
#     'compensation',
#     'paid',
#     'to',
#     'her',
#     '.']},
#   {'trigger text': 'divorce',
#    'trigger span': (9, 10),
#    'event type': 'Life:Divorce',
#    'arguments': {},
#    'passage': 'A judge ruled in February that depositions in the divorce case will remain confidential .',
#    'tokens': ['A',
#     'judge',
#     'ruled',
#     'in',
#     'February',
#     'that',
#     'depositions',
#     'in',
#     'the',
#     'divorce',
#     'case',
#     'will',
#     'remain',
#     'confidential',
#     '.']},
#   {'trigger text': 'retirement',
#    'trigger span': (17, 18),
#    'event type': 'Personnel:End-Position',
#    'arguments': {'Person': [{'argument text': 'Welch',
#       'argument span': (11, 12)}],
#     'Entity': [{'argument text': 'GE', 'argument span': (20, 21)}]},
#    'passage': 'Earlier documents in the case have included embarrassing details about perks Welch received as part of his retirement package from GE at a time when corporate scandals were sparking outrage .',
#    'tokens': ['Earlier',
#     'documents',
#     'in',
#     'the',
#     'case',
#     'have',
#     'included',
#     'embarrassing',
#     'details',
#     'about',
#     'perks',
#     'Welch',
#     'received',
#     'as',
#     'part',
#     'of',
#     'his',
#     'retirement',
#     'package',
#     'from',
#     'GE',
#     'at',
#     'a',
#     'time',
#     'when',
#     'corporate',
#     'scandals',
#     'were',
#     'sparking',
#     'outrage',
#     '.']},
#   {'trigger text': 'breakdowns',
#    'trigger span': (6, 7),
#    'event type': 'Life:Divorce',
#    'arguments': {'Person': [{'argument text': 'Welches',
#       'argument span': (9, 10)}]},
#    'passage': "Webb also said details of the breakdowns of the Welches ' previous marriages were likely to come up , and cited reports of alleged extramarital affairs by both .",
#    'tokens': ['Webb',
#     'also',
#     'said',
#     'details',
#     'of',
#     'the',
#     'breakdowns',
#     'of',
#     'the',
#     'Welches',
#     "'",
#     'previous',
#     'marriages',
#     'were',
#     'likely',
#     'to',
#     'come',
#     'up',
#     ',',
#     'and',
#     'cited',
#     'reports',
#     'of',
#     'alleged',
#     'extramarital',
#     'affairs',
#     'by',
#     'both',
#     '.']},
#   {'trigger text': 'marriages',
#    'trigger span': (12, 13),
#    'event type': 'Life:Marry',
#    'arguments': {'Person': [{'argument text': 'Welches',
#       'argument span': (9, 10)}]},
#    'passage': "Webb also said details of the breakdowns of the Welches ' previous marriages were likely to come up , and cited reports of alleged extramarital affairs by both .",
#    'tokens': ['Webb',
#     'also',
#     'said',
#     'details',
#     'of',
#     'the',
#     'breakdowns',
#     'of',
#     'the',
#     'Welches',
#     "'",
#     'previous',
#     'marriages',
#     'were',
#     'likely',
#     'to',
#     'come',
#     'up',
#     ',',
#     'and',
#     'cited',
#     'reports',
#     'of',
#     'alleged',
#     'extramarital',
#     'affairs',
#     'by',
#     'both',
#     '.']}]}

# %% [markdown]
# # Robustness

# %%
data["input"][0] = "Britis Chancellor of the Exchequr Gordon Browen on Tuedsay namd the current head of the countrys energy regulator as the new chaimran of finnce wachdog the Financil Services Authoriy (FSA) . <--triggerword--> named <--template--> <--Person--> [None] </--Person--> <--Agent--> [None] </--Agent--> <--Place--> [None] </--Place-->"

# %%
data["input"][1] = "Former seior banker Callumm McCarth begins what is one of the most impotant jobs in London's financial wrld in Septembr, when incmbent Howard Dais step down . <--triggerword--> Former <--template--> <--Person--> [None] </--Person--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->"
data["input"][2] = "Former seior banker Callumm McCarth begins what is one of the most impotant jobs in London's financial wrld in Septembr, when incmbent Howard Dais step down . <--triggerword--> begins <--template--> <--Person--> [None] </--Person--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->"

# %%
data["input"][3] = "Davies is leavig to becom chairman of the Lodon School of Ecnomics, on of the best-kown prts of the Universty of London . <--triggerword--> leaving <--template--> <--Person--> [None] </--Person--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->"
data["input"][4] = "Davies is leavig to becom chairman of the Lodon School of Ecnomics, on of the best-kown prts of the Universty of London . <--triggerword--> become <--template--> <--Person--> [None] </--Person--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->"

# %%
data["input"][5] = "As well as previously holding seneor postions at Barclys Bnk, BZW and Kleinwrt Bnson, McCrthy was frmerly a top cvil servant at the Deparment of Trade nd Indstry . <--triggerword--> previously <--template--> <--Person--> [None] </--Person--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->"
data["input"][6] = "As well as previously holding seneor postions at Barclys Bnk, BZW and Kleinwrt Bnson, McCrthy was frmerly a top cvil servant at the Deparment of Trade nd Indstry . <--triggerword--> formerly <--template--> <--Person--> [None] </--Person--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->"

# %%
data["input"][7] = "Russain Presidnt Vldimir Ptin's summit with the leeders of Germny and Frnce my have been a failur that proves there can be no long-term 'pece cmp' allianc following the end of wr in Ira, governmnt surces were quotd as sayng at the weekend . <--triggerword--> summit <--template--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->"
data["input"][8] = "Russain Presidnt Vldimir Ptin's summit with the leeders of Germny and Frnce my have been a failur that proves there can be no long-term 'pece cmp' allianc following the end of wr in Ira, governmnt surces were quotd as sayng at the weekend . <--triggerword--> war <--template--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->"

# %%
data["input"][9] = "The commnts indcate that Russia's nuancd positon over the wr in Ira was becoming evr mor scrmbled, with Putn pushng to prtect his buddng friendship with US Prsident George W. Bush in the face of strident opoosition from the Rusian media and other top Kremli officials . <--triggerword--> war <--template--> <--Attacker--> [None] </--Attacker--> <--Target--> [None] </--Target--> <--Instrument--> [None] </--Instrument--> <--Place--> [None] </--Place-->"

# %%
data["input"][10] = "Analyst have lng argud that Putin is far keener to presrve friedly relations with the Unitd Sttes than the pr-European, anti-wr camps embeded in much of the Rusian media and the foreign and defnse ministries . <--triggerword--> war <--template--> <--Attacker--> [None] </--Attacker--> <--Target--> [None] </--Target--> <--Instrument--> [None] </--Instrument--> <--Place--> [None] </--Place-->"

# %%
data["input"][:11]
# Out:
# ['Britis Chancellor of the Exchequr Gordon Browen on Tuedsay namd the current head of the countrys energy regulator as the new chaimran of finnce wachdog the Financil Services Authoriy (FSA) . <--triggerword--> named <--template--> <--Person--> [None] </--Person--> <--Agent--> [None] </--Agent--> <--Place--> [None] </--Place-->',
#  "Former seior banker Callumm McCarth begins what is one of the most impotant jobs in London's financial wrld in Septembr, when incmbent Howard Dais step down . <--triggerword--> Former <--template--> <--Person--> [None] </--Person--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->",
#  "Former seior banker Callumm McCarth begins what is one of the most impotant jobs in London's financial wrld in Septembr, when incmbent Howard Dais step down . <--triggerword--> begins <--template--> <--Person--> [None] </--Person--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->",
#  'Davies is leavig to becom chairman of the Lodon School of Ecnomics, on of the best-kown prts of the Universty of London . <--triggerword--> leaving <--template--> <--Person--> [None] </--Person--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->',
#  'Davies is leavig to becom chairman of the Lodon School of Ecnomics, on of the best-kown prts of the Universty of London . <--triggerword--> become <--template--> <--Person--> [None] </--Person--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->',
#  'As well as previously holding seneor postions at Barclys Bnk, BZW and Kleinwrt Bnson, McCrthy was frmerly a top cvil servant at the Deparment of Trade nd Indstry . <--triggerword--> previously <--template--> <--Person--> [None] </--Person--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->',
#  'As well as previously holding seneor postions at Barclys Bnk, BZW and Kleinwrt Bnson, McCrthy was frmerly a top cvil servant at the Deparment of Trade nd Indstry . <--triggerword--> formerly <--template--> <--Person--> [None] </--Person--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->',
#  "Russain Presidnt Vldimir Ptin's summit with the leeders of Germny and Frnce my have been a failur that proves there can be no long-term 'pece cmp' allianc following the end of wr in Ira, governmnt surces were quotd as sayng at the weekend . <--triggerword--> summit <--template--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->",
#  "Russain Presidnt Vldimir Ptin's summit with the leeders of Germny and Frnce my have been a failur that proves there can be no long-term 'pece cmp' allianc following the end of wr in Ira, governmnt surces were quotd as sayng at the weekend . <--triggerword--> war <--template--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->",
#  "The commnts indcate that Russia's nuancd positon over the wr in Ira was becoming evr mor scrmbled, with Putn pushng to prtect his buddng friendship with US Prsident George W. Bush in the face of strident opoosition from the Rusian media and other top Kremli officials . <--triggerword--> war <--template--> <--Attacker--> [None] </--Attacker--> <--Target--> [None] </--Target--> <--Instrument--> [None] </--Instrument--> <--Place--> [None] </--Place-->",
#  'Analyst have lng argud that Putin is far keener to presrve friedly relations with the Unitd Sttes than the pr-European, anti-wr camps embeded in much of the Rusian media and the foreign and defnse ministries . <--triggerword--> war <--template--> <--Attacker--> [None] </--Attacker--> <--Target--> [None] </--Target--> <--Instrument--> [None] </--Instrument--> <--Place--> [None] </--Place-->']

# %%
with open("test_all.pkl", 'wb') as file:
    # Write the dictionary to the pickle file
    pickle.dump(data, file)

# %% [markdown]
# # Taxonomy

# %%
temp = data
temp["input"][350:356]
# Out:
# ['Diller has served as head of Paramount and Twentieth Century Fox , where he helped launch the Fox Television network . <--triggerword--> launch <--template--> <--Agent--> [None] </--Agent--> <--Org--> [None] </--Org--> <--Place--> [None] </--Place-->',
#  "He started his entertainment career at ABC , where he is credited with creating the `` movie of the week '' concept . <--triggerword--> started <--template--> <--Person--> [None] </--Person--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->",
#  'U.S. and British troops were moving on the strategic southern port city of Basra Saturday after a massive aerial assault pounded Baghdad at dawn . <--triggerword--> moving <--template--> <--Artifact--> [None] </--Artifact--> <--Destination--> [None] </--Destination--> <--Origin--> [None] </--Origin--> <--Vehicle--> [None] </--Vehicle--> <--Agent--> [None] </--Agent--> <--Place--> [None] </--Place-->',
#  'U.S. and British troops were moving on the strategic southern port city of Basra Saturday after a massive aerial assault pounded Baghdad at dawn . <--triggerword--> pounded <--template--> <--Attacker--> [None] </--Attacker--> <--Target--> [None] </--Target--> <--Instrument--> [None] </--Instrument--> <--Place--> [None] </--Place-->',
#  'The battle for Basra , an oil hub of some 1.3 million people , was underway by midday , with coalition troops trying to surround Iraqi positions and force a surrender . <--triggerword--> battle <--template--> <--Attacker--> [None] </--Attacker--> <--Target--> [None] </--Target--> <--Instrument--> [None] </--Instrument--> <--Place--> [None] </--Place-->',
#  'U.S. aircraft bombed Iraqi tanks holding bridges close to the city . <--triggerword--> bombed <--template--> <--Attacker--> [None] </--Attacker--> <--Target--> [None] </--Target--> <--Instrument--> [None] </--Instrument--> <--Place--> [None] </--Place-->']

# %%
temp["input"][350] = "Diller has held leadership positions at Paramount and Twentieth Century Fox, where he played a key role in launching the Fox Television network . <--triggerword--> launching <--template--> <--Agent--> [None] </--Agent--> <--Org--> [None] </--Org--> <--Place--> [None] </--Place-->"
temp["input"][351] = "He began his career in the entertainment industry at ABC, where he is recognized for creating the concept of movie of the week . <--triggerword--> began <--template--> <--Person--> [None] </--Person--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->"
temp["input"][352] = "On Saturday, American and British forces were advancing towards the strategically important southern port city of Basra following a large-scale air attack on Baghdad at dawn . <--triggerword--> advancing <--template--> <--Artifact--> [None] </--Artifact--> <--Destination--> [None] </--Destination--> <--Origin--> [None] </--Origin--> <--Vehicle--> [None] </--Vehicle--> <--Agent--> [None] </--Agent--> <--Place--> [None] </--Place-->"
temp["input"][353] = "American and British troops were making their way towards Basra, a vital southern port city, on Saturday after a significant aerial bombardment of Baghdad early in the morning . <--triggerword--> bombardment <--template--> <--Attacker--> [None] </--Attacker--> <--Target--> [None] </--Target--> <--Instrument--> [None] </--Instrument--> <--Place--> [None] </--Place-->"
temp["input"][354] = "The fight for Basra, a city with a population of around 1.3 million and an important oil center, commenced around midday as coalition forces aimed to encircle Iraqi positions and compel a surrender . <--triggerword--> fight <--template--> <--Attacker--> [None] </--Attacker--> <--Target--> [None] </--Target--> <--Instrument--> [None] </--Instrument--> <--Place--> [None] </--Place-->"
temp["input"][355] = "U.S. military aircraft targeted Iraqi tanks positioned near the city's bridges, conducting airstrikes . <--triggerword--> targeted <--template--> <--Attacker--> [None] </--Attacker--> <--Target--> [None] </--Target--> <--Instrument--> [None] </--Instrument--> <--Place--> [None] </--Place-->"

# %% [markdown]
# # Fairness

# %%
temp["input"][234:239]
# Out:
# ['Scott told police she did not tend to the baby , and it died after 30 minutes . <--triggerword--> died <--template--> <--Agent--> [None] </--Agent--> <--Victim--> [None] </--Victim--> <--Instrument--> [None] </--Instrument--> <--Place--> [None] </--Place-->',
#  'She said the baby had to die , according to the criminal complaint . <--triggerword--> die <--template--> <--Agent--> [None] </--Agent--> <--Victim--> [None] </--Victim--> <--Instrument--> [None] </--Instrument--> <--Place--> [None] </--Place-->',
#  'Scott told investigators she had moved that body around before she moved to Texas , sometimes in the closet at the Byrds Creek house , in the trunk of her car and in the closet of her apartment in Richland Center , the complaint said . <--triggerword--> moved <--template--> <--Artifact--> [None] </--Artifact--> <--Destination--> [None] </--Destination--> <--Origin--> [None] </--Origin--> <--Vehicle--> [None] </--Vehicle--> <--Agent--> [None] </--Agent--> <--Place--> [None] </--Place-->',
#  'Scott told investigators she had moved that body around before she moved to Texas , sometimes in the closet at the Byrds Creek house , in the trunk of her car and in the closet of her apartment in Richland Center , the complaint said . <--triggerword--> moved <--template--> <--Artifact--> [None] </--Artifact--> <--Destination--> [None] </--Destination--> <--Origin--> [None] </--Origin--> <--Vehicle--> [None] </--Vehicle--> <--Agent--> [None] </--Agent--> <--Place--> [None] </--Place-->',
#  'Supermodel Rachel Hunter on Tuesday filed for divorce from her estranged rocker husband Rod Stewart , four years after the couple separated , court papers showed . <--triggerword--> divorce <--template--> <--Person--> [None] </--Person--> <--Place--> [None] </--Place-->']

# %%
temp["input"][234] = "Alex told police he did not tend to the baby, and it died after 30 minutes . <--triggerword--> died <--template--> <--Agent--> [None] </--Agent--> <--Victim--> [None] </--Victim--> <--Instrument--> [None] </--Instrument--> <--Place--> [None] </--Place-->"
temp["input"][235] = "They said the baby had to die, according to the criminal complaint . <--triggerword--> die <--template--> <--Agent--> [None] </--Agent--> <--Victim--> [None] </--Victim--> <--Instrument--> [None] </--Instrument--> <--Place--> [None] </--Place-->"
temp["input"][236] = "Alex told investigators he had moved that body around before they moved to Texas, sometimes in the closet at the Byrds Creek house, in the trunk of his car, and in the closet of his apartment in Richland Center, the complaint said . <--triggerword--> moved <--template--> <--Artifact--> [None] </--Artifact--> <--Destination--> [None] </--Destination--> <--Origin--> [None] </--Origin--> <--Vehicle--> [None] </--Vehicle--> <--Agent--> [None] </--Agent--> <--Place--> [None] </--Place-->"
temp["input"][237] = "Alex told investigators he had moved that body around before they moved to Texas, sometimes in the closet at the Byrds Creek house, in the trunk of his car, and in the closet of his apartment in Richland Center, the complaint said . <--triggerword--> moved <--template--> <--Artifact--> [None] </--Artifact--> <--Destination--> [None] </--Destination--> <--Origin--> [None] </--Origin--> <--Vehicle--> [None] </--Vehicle--> <--Agent--> [None] </--Agent--> <--Place--> [None] </--Place-->"
temp["input"][238] = "Supermodel Ryan Hunter on Tuesday filed for divorce from his estranged musician spouse Ron Stewart, four years after the couple separated, court papers showed . <--triggerword--> divorce <--template--> <--Person--> [None] </--Person--> <--Place--> [None] </--Place-->"

# %% [markdown]
# # Negations

# %%
temp["input"][173:178]
# Out:
# ['Officials from Iraqi groups that met with Bremer last week have said that he back peddled on what they said were earlier pledges to give them a lead role in forming a new interim government in the next few weeks . <--triggerword--> met <--template--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->',
#  '" We understand that they want to have as much power as possible but we told them : \' You wo n\'t be directly elected , you wo n\'t have any direct experience of government , " the source said . <--triggerword--> elected <--template--> <--Person--> [None] </--Person--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->',
#  '" \' Of course you will have input into the government but , since you are not directly elected , it would be a nonsense for you to have direct executive power , \' the source said . <--triggerword--> elected <--template--> <--Person--> [None] </--Person--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->',
#  'The comments came on the same day that a prominent Iraqi called for internationally - supervised elections in Iraq . <--triggerword--> elections <--template--> <--Person--> [None] </--Person--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->',
#  'Adnan Pachachi , a onetime foreign minister who returned to Iraq on May 6 after 33 years in exile , told the independent Az - Zaman daily that elections should be held under international supervision . <--triggerword--> returned <--template--> <--Artifact--> [None] </--Artifact--> <--Destination--> [None] </--Destination--> <--Origin--> [None] </--Origin--> <--Vehicle--> [None] </--Vehicle--> <--Agent--> [None] </--Agent--> <--Place--> [None] </--Place-->']

# %%
temp["input"][173] = 'Officials from Iraqi groups that met with Bremer last week have said that he did not backpedal on what they said were earlier pledges to give them a lead role in forming a new interim government in the next few weeks . <--triggerword--> met <--template--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->'
temp["input"][174] = '" We understand that they do not want to have as much power as possible, but we told them : \' "You wo n\'t be directly elected, you wo n\'t have any direct experience of government , " the source said . <--triggerword--> elected <--template--> <--Person--> [None] </--Person--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->'
temp["input"][175] = '" \' Of course , you will not have input into the government , but since you are directly elected , it would not be a nonsense for you to have direct executive power , \' the source said . <--triggerword--> elected <--template--> <--Person--> [None] </--Person--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->'
temp["input"][176] = 'The comments did not come on the same day that a prominent Iraqi called for internationally - supervised elections in Iraq . <--triggerword--> elections <--template--> <--Person--> [None] </--Person--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->'
temp["input"][177] = 'Adnan Pachachi , a onetime foreign minister who did not return to Iraq on May 6 after 33 years in exile , told the independent Az - Zaman daily that elections should not be held under international supervision . <--triggerword--> returned <--template--> <--Artifact--> [None] </--Artifact--> <--Destination--> [None] </--Destination--> <--Origin--> [None] </--Origin--> <--Vehicle--> [None] </--Vehicle--> <--Agent--> [None] </--Agent--> <--Place--> [None] </--Place-->'

# %%
temp["input"][176]
# Out:
# ('The comments did not come on the same day that a prominent Iraqi called for internationally - supervised elections in Iraq . <--triggerword--> elections <--template--> <--Person--> [None] </--Person--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->',)

# %% [markdown]
# # Write new file

# %%
new_data = {'input' : [], 'target' : [],  'all' : []}
new_data["input"] = data["input"][:11] + temp["input"][350:356] + temp["input"][234:239] + temp["input"][173:178]
new_data["target"] = data["target"][:11] + temp["target"][350:356] + temp["target"][234:239] + temp["target"][173:178]
new_data["all"] = data["all"][:11] + temp["all"][350:356] + temp["all"][234:239] + temp["all"][173:178]

# %%
with open("test_all.pkl", 'wb') as file:
    # Write the dictionary to the pickle file
    pickle.dump(new_data, file)

# %%
with open('test_all.pkl', 'rb') as file:
    _data = pickle.load(file)
_data
# Out:
# {'input': ['Britis Chancellor of the Exchequr Gordon Browen on Tuedsay namd the current head of the countrys energy regulator as the new chaimran of finnce wachdog the Financil Services Authoriy (FSA) . <--triggerword--> named <--template--> <--Person--> [None] </--Person--> <--Agent--> [None] </--Agent--> <--Place--> [None] </--Place-->',
#   "Former seior banker Callumm McCarth begins what is one of the most impotant jobs in London's financial wrld in Septembr, when incmbent Howard Dais step down . <--triggerword--> Former <--template--> <--Person--> [None] </--Person--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->",
#   "Former seior banker Callumm McCarth begins what is one of the most impotant jobs in London's financial wrld in Septembr, when incmbent Howard Dais step down . <--triggerword--> begins <--template--> <--Person--> [None] </--Person--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->",
#   'Davies is leavig to becom chairman of the Lodon School of Ecnomics, on of the best-kown prts of the Universty of London . <--triggerword--> leaving <--template--> <--Person--> [None] </--Person--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->',
#   'Davies is leavig to becom chairman of the Lodon School of Ecnomics, on of the best-kown prts of the Universty of London . <--triggerword--> become <--template--> <--Person--> [None] </--Person--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->',
#   'As well as previously holding seneor postions at Barclys Bnk, BZW and Kleinwrt Bnson, McCrthy was frmerly a top cvil servant at the Deparment of Trade nd Indstry . <--triggerword--> previously <--template--> <--Person--> [None] </--Person--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->',
#   'As well as previously holding seneor postions at Barclys Bnk, BZW and Kleinwrt Bnson, McCrthy was frmerly a top cvil servant at the Deparment of Trade nd Indstry . <--triggerword--> formerly <--template--> <--Person--> [None] </--Person--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->',
#   "Russain Presidnt Vldimir Ptin's summit with the leeders of Germny and Frnce my have been a failur that proves there can be no long-term 'pece cmp' allianc following the end of wr in Ira, governmnt surces were quotd as sayng at the weekend . <--triggerword--> summit <--template--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->",
#   "Russain Presidnt Vldimir Ptin's summit with the leeders of Germny and Frnce my have been a failur that proves there can be no long-term 'pece cmp' allianc following the end of wr in Ira, governmnt surces were quotd as sayng at the weekend . <--triggerword--> war <--template--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->",
#   "The commnts indcate that Russia's nuancd positon over the wr in Ira was becoming evr mor scrmbled, with Putn pushng to prtect his buddng friendship with US Prsident George W. Bush in the face of strident opoosition from the Rusian media and other top Kremli officials . <--triggerword--> war <--template--> <--Attacker--> [None] </--Attacker--> <--Target--> [None] </--Target--> <--Instrument--> [None] </--Instrument--> <--Place--> [None] </--Place-->",
#   'Analyst have lng argud that Putin is far keener to presrve friedly relations with the Unitd Sttes than the pr-European, anti-wr camps embeded in much of the Rusian media and the foreign and defnse ministries . <--triggerword--> war <--template--> <--Attacker--> [None] </--Attacker--> <--Target--> [None] </--Target--> <--Instrument--> [None] </--Instrument--> <--Place--> [None] </--Place-->',
#   'Diller has held leadership positions at Paramount and Twentieth Century Fox, where he played a key role in launching the Fox Television network . <--triggerword--> launching <--template--> <--Agent--> [None] </--Agent--> <--Org--> [None] </--Org--> <--Place--> [None] </--Place-->',
#   'He began his career in the entertainment industry at ABC, where he is recognized for creating the concept of movie of the week . <--triggerword--> began <--template--> <--Person--> [None] </--Person--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->',
#   'On Saturday, American and British forces were advancing towards the strategically important southern port city of Basra following a large-scale air attack on Baghdad at dawn . <--triggerword--> advancing <--template--> <--Artifact--> [None] </--Artifact--> <--Destination--> [None] </--Destination--> <--Origin--> [None] </--Origin--> <--Vehicle--> [None] </--Vehicle--> <--Agent--> [None] </--Agent--> <--Place--> [None] </--Place-->',
#   'American and British troops were making their way towards Basra, a vital southern port city, on Saturday after a significant aerial bombardment of Baghdad early in the morning . <--triggerword--> bombardment <--template--> <--Attacker--> [None] </--Attacker--> <--Target--> [None] </--Target--> <--Instrument--> [None] </--Instrument--> <--Place--> [None] </--Place-->',
#   'The fight for Basra, a city with a population of around 1.3 million and an important oil center, commenced around midday as coalition forces aimed to encircle Iraqi positions and compel a surrender . <--triggerword--> fight <--template--> <--Attacker--> [None] </--Attacker--> <--Target--> [None] </--Target--> <--Instrument--> [None] </--Instrument--> <--Place--> [None] </--Place-->',
#   "U.S. military aircraft targeted Iraqi tanks positioned near the city's bridges, conducting airstrikes . <--triggerword--> targeted <--template--> <--Attacker--> [None] </--Attacker--> <--Target--> [None] </--Target--> <--Instrument--> [None] </--Instrument--> <--Place--> [None] </--Place-->",
#   'Alex told police he did not tend to the baby, and it died after 30 minutes . <--triggerword--> died <--template--> <--Agent--> [None] </--Agent--> <--Victim--> [None] </--Victim--> <--Instrument--> [None] </--Instrument--> <--Place--> [None] </--Place-->',
#   'They said the baby had to die, according to the criminal complaint . <--triggerword--> die <--template--> <--Agent--> [None] </--Agent--> <--Victim--> [None] </--Victim--> <--Instrument--> [None] </--Instrument--> <--Place--> [None] </--Place-->',
#   'Alex told investigators he had moved that body around before they moved to Texas, sometimes in the closet at the Byrds Creek house, in the trunk of his car, and in the closet of his apartment in Richland Center, the complaint said . <--triggerword--> moved <--template--> <--Artifact--> [None] </--Artifact--> <--Destination--> [None] </--Destination--> <--Origin--> [None] </--Origin--> <--Vehicle--> [None] </--Vehicle--> <--Agent--> [None] </--Agent--> <--Place--> [None] </--Place-->',
#   'Alex told investigators he had moved that body around before they moved to Texas, sometimes in the closet at the Byrds Creek house, in the trunk of his car, and in the closet of his apartment in Richland Center, the complaint said . <--triggerword--> moved <--template--> <--Artifact--> [None] </--Artifact--> <--Destination--> [None] </--Destination--> <--Origin--> [None] </--Origin--> <--Vehicle--> [None] </--Vehicle--> <--Agent--> [None] </--Agent--> <--Place--> [None] </--Place-->',
#   'Supermodel Ryan Hunter on Tuesday filed for divorce from his estranged musician spouse Ron Stewart, four years after the couple separated, court papers showed . <--triggerword--> divorce <--template--> <--Person--> [None] </--Person--> <--Place--> [None] </--Place-->',
#   'Officials from Iraqi groups that met with Bremer last week have said that he did not backpedal on what they said were earlier pledges to give them a lead role in forming a new interim government in the next few weeks . <--triggerword--> met <--template--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->',
#   '" We understand that they do not want to have as much power as possible, but we told them : \' "You wo n\'t be directly elected, you wo n\'t have any direct experience of government , " the source said . <--triggerword--> elected <--template--> <--Person--> [None] </--Person--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->',
#   '" \' Of course , you will not have input into the government , but since you are directly elected , it would not be a nonsense for you to have direct executive power , \' the source said . <--triggerword--> elected <--template--> <--Person--> [None] </--Person--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->',
#   'The comments did not come on the same day that a prominent Iraqi called for internationally - supervised elections in Iraq . <--triggerword--> elections <--template--> <--Person--> [None] </--Person--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->',
#   'Adnan Pachachi , a onetime foreign minister who did not return to Iraq on May 6 after 33 years in exile , told the independent Az - Zaman daily that elections should not be held under international supervision . <--triggerword--> returned <--template--> <--Artifact--> [None] </--Artifact--> <--Destination--> [None] </--Destination--> <--Origin--> [None] </--Origin--> <--Vehicle--> [None] </--Vehicle--> <--Agent--> [None] </--Agent--> <--Place--> [None] </--Place-->'],
#  'target': ['<--Person--> head </--Person--> <--Agent--> [None] </--Agent--> <--Place--> [None] </--Place-->',
#   '<--Person--> Callum McCarthy </--Person--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->',
#   '<--Person--> Callum McCarthy </--Person--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->',
#   '<--Person--> Davies </--Person--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->',
#   '<--Person--> Davies </--Person--> <--Entity--> London School of Economics </--Entity--> <--Place--> [None] </--Place-->',
#   '<--Person--> McCarthy </--Person--> <--Entity--> Barclays Bank [and] BZW [and] Kleinwort Benson </--Entity--> <--Place--> [None] </--Place-->',
#   '<--Person--> McCarthy </--Person--> <--Entity--> Department of Trade and Industry </--Entity--> <--Place--> [None] </--Place-->',
#   '<--Entity--> Vladimir Putin [and] leaders </--Entity--> <--Place--> [None] </--Place-->',
#   '<--Attacker--> [None] </--Attacker--> <--Target--> [None] </--Target--> <--Instrument--> [None] </--Instrument--> <--Place--> Iraq </--Place-->',
#   '<--Attacker--> [None] </--Attacker--> <--Target--> [None] </--Target--> <--Instrument--> [None] </--Instrument--> <--Place--> Iraq </--Place-->',
#   '<--Attacker--> [None] </--Attacker--> <--Target--> [None] </--Target--> <--Instrument--> [None] </--Instrument--> <--Place--> [None] </--Place-->',
#   '<--Agent--> Twentieth Century Fox </--Agent--> <--Org--> network </--Org--> <--Place--> [None] </--Place-->',
#   '<--Person--> [None] </--Person--> <--Entity--> ABC </--Entity--> <--Place--> [None] </--Place-->',
#   '<--Artifact--> troops </--Artifact--> <--Destination--> city </--Destination--> <--Origin--> [None] </--Origin--> <--Vehicle--> [None] </--Vehicle--> <--Agent--> [None] </--Agent--> <--Place--> [None] </--Place-->',
#   '<--Attacker--> [None] </--Attacker--> <--Target--> [None] </--Target--> <--Instrument--> [None] </--Instrument--> <--Place--> Baghdad </--Place-->',
#   '<--Attacker--> [None] </--Attacker--> <--Target--> positions </--Target--> <--Instrument--> [None] </--Instrument--> <--Place--> Basra </--Place-->',
#   '<--Attacker--> U.S. </--Attacker--> <--Target--> [None] </--Target--> <--Instrument--> aircraft </--Instrument--> <--Place--> bridges </--Place-->',
#   '<--Agent--> [None] </--Agent--> <--Victim--> [None] </--Victim--> <--Instrument--> [None] </--Instrument--> <--Place--> [None] </--Place-->',
#   '<--Agent--> [None] </--Agent--> <--Victim--> baby </--Victim--> <--Instrument--> [None] </--Instrument--> <--Place--> [None] </--Place-->',
#   '<--Artifact--> body </--Artifact--> <--Destination--> closet [and] closet </--Destination--> <--Origin--> [None] </--Origin--> <--Vehicle--> [None] </--Vehicle--> <--Agent--> [None] </--Agent--> <--Place--> [None] </--Place-->',
#   '<--Artifact--> [None] </--Artifact--> <--Destination--> Texas </--Destination--> <--Origin--> [None] </--Origin--> <--Vehicle--> [None] </--Vehicle--> <--Agent--> [None] </--Agent--> <--Place--> [None] </--Place-->',
#   '<--Person--> Rachel Hunter [and] husband </--Person--> <--Place--> [None] </--Place-->',
#   '<--Entity--> Bremer </--Entity--> <--Place--> [None] </--Place-->',
#   '<--Person--> [None] </--Person--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->',
#   '<--Person--> [None] </--Person--> <--Entity--> [None] </--Entity--> <--Place--> [None] </--Place-->',
#   '<--Person--> [None] </--Person--> <--Entity--> [None] </--Entity--> <--Place--> Iraq </--Place-->',
#   '<--Artifact--> [None] </--Artifact--> <--Destination--> Iraq </--Destination--> <--Origin--> [None] </--Origin--> <--Vehicle--> [None] </--Vehicle--> <--Agent--> [None] </--Agent--> <--Place--> [None] </--Place-->'],
#  'all': [{'trigger text': 'named',
#    'trigger span': (9, 10),
#    'event type': 'Personnel:Nominate',
#    'arguments': {'Person': [{'argument text': 'head',
#       'argument span': (12, 13)}]},
#    'passage': "British Chancellor of the Exchequer Gordon Brown on Tuesday named the current head of the country 's energy regulator as the new chairman of finance watchdog the Financial Services Authority ( FSA ) .",
#    'tokens': ['British',
#     'Chancellor',
#     'of',
#     'the',
#     'Exchequer',
#     'Gordon',
#     'Brown',
#     'on',
#     'Tuesday',
#     'named',
#     'the',
#     'current',
#     'head',
#     'of',
#     'the',
#     'country',
#     "'s",
#     'energy',
#     'regulator',
#     'as',
#     'the',
#     'new',
#     'chairman',
#     'of',
#     'finance',
#     'watchdog',
#     'the',
#     'Financial',
#     'Services',
#     'Authority',
#     '(',
#     'FSA',
#     ')',
#     '.']},
#   {'trigger text': 'Former',
#    'trigger span': (0, 1),
#    'event type': 'Personnel:End-Position',
#    'arguments': {'Person': [{'argument text': 'Callum McCarthy',
#       'argument span': (3, 5)}]},
#    'passage': "Former senior banker Callum McCarthy begins what is one of the most important jobs in London 's financial world in September , when incumbent Howard Davies steps down .",
#    'tokens': ['Former',
#     'senior',
#     'banker',
#     'Callum',
#     'McCarthy',
#     'begins',
#     'what',
#     'is',
#     'one',
#     'of',
#     'the',
#     'most',
#     'important',
#     'jobs',
#     'in',
#     'London',
#     "'s",
#     'financial',
#     'world',
#     'in',
#     'September',
#     ',',
#     'when',
#     'incumbent',
#     'Howard',
#     'Davies',
#     'steps',
#     'down',
#     '.']},
#   {'trigger text': 'begins',
#    'trigger span': (5, 6),
#    'event type': 'Personnel:Start-Position',
#    'arguments': {'Person': [{'argument text': 'Callum McCarthy',
#       'argument span': (3, 5)}]},
#    'passage': "Former senior banker Callum McCarthy begins what is one of the most important jobs in London 's financial world in September , when incumbent Howard Davies steps down .",
#    'tokens': ['Former',
#     'senior',
#     'banker',
#     'Callum',
#     'McCarthy',
#     'begins',
#     'what',
#     'is',
#     'one',
#     'of',
#     'the',
#     'most',
#     'important',
#     'jobs',
#     'in',
#     'London',
#     "'s",
#     'financial',
#     'world',
#     'in',
#     'September',
#     ',',
#     'when',
#     'incumbent',
#     'Howard',
#     'Davies',
#     'steps',
#     'down',
#     '.']},
#   {'trigger text': 'leaving',
#    'trigger span': (2, 3),
#    'event type': 'Personnel:End-Position',
#    'arguments': {'Person': [{'argument text': 'Davies',
#       'argument span': (0, 1)}]},
#    'passage': 'Davies is leaving to become chairman of the London School of Economics , one of the best - known parts of the University of London .',
#    'tokens': ['Davies',
#     'is',
#     'leaving',
#     'to',
#     'become',
#     'chairman',
#     'of',
#     'the',
#     'London',
#     'School',
#     'of',
#     'Economics',
#     ',',
#     'one',
#     'of',
#     'the',
#     'best',
#     '-',
#     'known',
#     'parts',
#     'of',
#     'the',
#     'University',
#     'of',
#     'London',
#     '.']},
#   {'trigger text': 'become',
#    'trigger span': (4, 5),
#    'event type': 'Personnel:Start-Position',
#    'arguments': {'Person': [{'argument text': 'Davies',
#       'argument span': (0, 1)}],
#     'Entity': [{'argument text': 'London School of Economics',
#       'argument span': (8, 12)}]},
#    'passage': 'Davies is leaving to become chairman of the London School of Economics , one of the best - known parts of the University of London .',
#    'tokens': ['Davies',
#     'is',
#     'leaving',
#     'to',
#     'become',
#     'chairman',
#     'of',
#     'the',
#     'London',
#     'School',
#     'of',
#     'Economics',
#     ',',
#     'one',
#     'of',
#     'the',
#     'best',
#     '-',
#     'known',
#     'parts',
#     'of',
#     'the',
#     'University',
#     'of',
#     'London',
#     '.']},
#   {'trigger text': 'previously',
#    'trigger span': (3, 4),
#    'event type': 'Personnel:End-Position',
#    'arguments': {'Entity': [{'argument text': 'Barclays Bank',
#       'argument span': (8, 10)},
#      {'argument text': 'BZW', 'argument span': (11, 12)},
#      {'argument text': 'Kleinwort Benson', 'argument span': (13, 15)}],
#     'Person': [{'argument text': 'McCarthy', 'argument span': (16, 17)}]},
#    'passage': 'As well as previously holding senior positions at Barclays Bank , BZW and Kleinwort Benson , McCarthy was formerly a top civil servant at the Department of Trade and Industry .',
#    'tokens': ['As',
#     'well',
#     'as',
#     'previously',
#     'holding',
#     'senior',
#     'positions',
#     'at',
#     'Barclays',
#     'Bank',
#     ',',
#     'BZW',
#     'and',
#     'Kleinwort',
#     'Benson',
#     ',',
#     'McCarthy',
#     'was',
#     'formerly',
#     'a',
#     'top',
#     'civil',
#     'servant',
#     'at',
#     'the',
#     'Department',
#     'of',
#     'Trade',
#     'and',
#     'Industry',
#     '.']},
#   {'trigger text': 'formerly',
#    'trigger span': (18, 19),
#    'event type': 'Personnel:End-Position',
#    'arguments': {'Person': [{'argument text': 'McCarthy',
#       'argument span': (16, 17)}],
#     'Entity': [{'argument text': 'Department of Trade and Industry',
#       'argument span': (25, 30)}]},
#    'passage': 'As well as previously holding senior positions at Barclays Bank , BZW and Kleinwort Benson , McCarthy was formerly a top civil servant at the Department of Trade and Industry .',
#    'tokens': ['As',
#     'well',
#     'as',
#     'previously',
#     'holding',
#     'senior',
#     'positions',
#     'at',
#     'Barclays',
#     'Bank',
#     ',',
#     'BZW',
#     'and',
#     'Kleinwort',
#     'Benson',
#     ',',
#     'McCarthy',
#     'was',
#     'formerly',
#     'a',
#     'top',
#     'civil',
#     'servant',
#     'at',
#     'the',
#     'Department',
#     'of',
#     'Trade',
#     'and',
#     'Industry',
#     '.']},
#   {'trigger text': 'summit',
#    'trigger span': (5, 6),
#    'event type': 'Contact:Meet',
#    'arguments': {'Entity': [{'argument text': 'Vladimir Putin',
#       'argument span': (2, 4)},
#      {'argument text': 'leaders', 'argument span': (8, 9)}]},
#    'passage': 'Russian President Vladimir Putin \'s summit with the leaders of Germany and France may have been a failure that proves there can be no long - term " peace camp " alliance following the end of war in Iraq , government sources were quoted as saying at the weekend .',
#    'tokens': ['Russian',
#     'President',
#     'Vladimir',
#     'Putin',
#     "'s",
#     'summit',
#     'with',
#     'the',
#     'leaders',
#     'of',
#     'Germany',
#     'and',
#     'France',
#     'may',
#     'have',
#     'been',
#     'a',
#     'failure',
#     'that',
#     'proves',
#     'there',
#     'can',
#     'be',
#     'no',
#     'long',
#     '-',
#     'term',
#     '"',
#     'peace',
#     'camp',
#     '"',
#     'alliance',
#     'following',
#     'the',
#     'end',
#     'of',
#     'war',
#     'in',
#     'Iraq',
#     ',',
#     'government',
#     'sources',
#     'were',
#     'quoted',
#     'as',
#     'saying',
#     'at',
#     'the',
#     'weekend',
#     '.']},
#   {'trigger text': 'war',
#    'trigger span': (36, 37),
#    'event type': 'Conflict:Attack',
#    'arguments': {'Place': [{'argument text': 'Iraq',
#       'argument span': (38, 39)}]},
#    'passage': 'Russian President Vladimir Putin \'s summit with the leaders of Germany and France may have been a failure that proves there can be no long - term " peace camp " alliance following the end of war in Iraq , government sources were quoted as saying at the weekend .',
#    'tokens': ['Russian',
#     'President',
#     'Vladimir',
#     'Putin',
#     "'s",
#     'summit',
#     'with',
#     'the',
#     'leaders',
#     'of',
#     'Germany',
#     'and',
#     'France',
#     'may',
#     'have',
#     'been',
#     'a',
#     'failure',
#     'that',
#     'proves',
#     'there',
#     'can',
#     'be',
#     'no',
#     'long',
#     '-',
#     'term',
#     '"',
#     'peace',
#     'camp',
#     '"',
#     'alliance',
#     'following',
#     'the',
#     'end',
#     'of',
#     'war',
#     'in',
#     'Iraq',
#     ',',
#     'government',
#     'sources',
#     'were',
#     'quoted',
#     'as',
#     'saying',
#     'at',
#     'the',
#     'weekend',
#     '.']},
#   {'trigger text': 'war',
#    'trigger span': (10, 11),
#    'event type': 'Conflict:Attack',
#    'arguments': {'Place': [{'argument text': 'Iraq',
#       'argument span': (12, 13)}]},
#    'passage': "The comments indicate that Russia 's nuanced position over the war in Iraq was becoming ever more scrambled , with Putin pushing to protect his budding friendship with US President George W. Bush in the face of strident opposition from the Russian media and other top Kremlin officials .",
#    'tokens': ['The',
#     'comments',
#     'indicate',
#     'that',
#     'Russia',
#     "'s",
#     'nuanced',
#     'position',
#     'over',
#     'the',
#     'war',
#     'in',
#     'Iraq',
#     'was',
#     'becoming',
#     'ever',
#     'more',
#     'scrambled',
#     ',',
#     'with',
#     'Putin',
#     'pushing',
#     'to',
#     'protect',
#     'his',
#     'budding',
#     'friendship',
#     'with',
#     'US',
#     'President',
#     'George',
#     'W.',
#     'Bush',
#     'in',
#     'the',
#     'face',
#     'of',
#     'strident',
#     'opposition',
#     'from',
#     'the',
#     'Russian',
#     'media',
#     'and',
#     'other',
#     'top',
#     'Kremlin',
#     'officials',
#     '.']},
#   {'trigger text': 'war',
#    'trigger span': (25, 26),
#    'event type': 'Conflict:Attack',
#    'arguments': {},
#    'passage': 'Analysts have long argued that Putin is far keener to preserve friendly relations with the United States than the pro - European , anti - war camps embedded in much of the Russian media and the foreign and defense ministries .',
#    'tokens': ['Analysts',
#     'have',
#     'long',
#     'argued',
#     'that',
#     'Putin',
#     'is',
#     'far',
#     'keener',
#     'to',
#     'preserve',
#     'friendly',
#     'relations',
#     'with',
#     'the',
#     'United',
#     'States',
#     'than',
#     'the',
#     'pro',
#     '-',
#     'European',
#     ',',
#     'anti',
#     '-',
#     'war',
#     'camps',
#     'embedded',
#     'in',
#     'much',
#     'of',
#     'the',
#     'Russian',
#     'media',
#     'and',
#     'the',
#     'foreign',
#     'and',
#     'defense',
#     'ministries',
#     '.']},
#   {'trigger text': 'launch',
#    'trigger span': (15, 16),
#    'event type': 'Business:Start-Org',
#    'arguments': {'Agent': [{'argument text': 'Twentieth Century Fox',
#       'argument span': (8, 11)}],
#     'Org': [{'argument text': 'network', 'argument span': (19, 20)}]},
#    'passage': 'Diller has served as head of Paramount and Twentieth Century Fox , where he helped launch the Fox Television network .',
#    'tokens': ['Diller',
#     'has',
#     'served',
#     'as',
#     'head',
#     'of',
#     'Paramount',
#     'and',
#     'Twentieth',
#     'Century',
#     'Fox',
#     ',',
#     'where',
#     'he',
#     'helped',
#     'launch',
#     'the',
#     'Fox',
#     'Television',
#     'network',
#     '.']},
#   {'trigger text': 'started',
#    'trigger span': (1, 2),
#    'event type': 'Personnel:Start-Position',
#    'arguments': {'Entity': [{'argument text': 'ABC',
#       'argument span': (6, 7)}]},
#    'passage': "He started his entertainment career at ABC , where he is credited with creating the `` movie of the week '' concept .",
#    'tokens': ['He',
#     'started',
#     'his',
#     'entertainment',
#     'career',
#     'at',
#     'ABC',
#     ',',
#     'where',
#     'he',
#     'is',
#     'credited',
#     'with',
#     'creating',
#     'the',
#     '``',
#     'movie',
#     'of',
#     'the',
#     'week',
#     "''",
#     'concept',
#     '.']},
#   {'trigger text': 'moving',
#    'trigger span': (5, 6),
#    'event type': 'Movement:Transport',
#    'arguments': {'Artifact': [{'argument text': 'troops',
#       'argument span': (3, 4)}],
#     'Destination': [{'argument text': 'city', 'argument span': (11, 12)}]},
#    'passage': 'U.S. and British troops were moving on the strategic southern port city of Basra Saturday after a massive aerial assault pounded Baghdad at dawn .',
#    'tokens': ['U.S.',
#     'and',
#     'British',
#     'troops',
#     'were',
#     'moving',
#     'on',
#     'the',
#     'strategic',
#     'southern',
#     'port',
#     'city',
#     'of',
#     'Basra',
#     'Saturday',
#     'after',
#     'a',
#     'massive',
#     'aerial',
#     'assault',
#     'pounded',
#     'Baghdad',
#     'at',
#     'dawn',
#     '.']},
#   {'trigger text': 'pounded',
#    'trigger span': (20, 21),
#    'event type': 'Conflict:Attack',
#    'arguments': {'Place': [{'argument text': 'Baghdad',
#       'argument span': (21, 22)}]},
#    'passage': 'U.S. and British troops were moving on the strategic southern port city of Basra Saturday after a massive aerial assault pounded Baghdad at dawn .',
#    'tokens': ['U.S.',
#     'and',
#     'British',
#     'troops',
#     'were',
#     'moving',
#     'on',
#     'the',
#     'strategic',
#     'southern',
#     'port',
#     'city',
#     'of',
#     'Basra',
#     'Saturday',
#     'after',
#     'a',
#     'massive',
#     'aerial',
#     'assault',
#     'pounded',
#     'Baghdad',
#     'at',
#     'dawn',
#     '.']},
#   {'trigger text': 'battle',
#    'trigger span': (1, 2),
#    'event type': 'Conflict:Attack',
#    'arguments': {'Place': [{'argument text': 'Basra',
#       'argument span': (3, 4)}],
#     'Target': [{'argument text': 'positions', 'argument span': (26, 27)}]},
#    'passage': 'The battle for Basra , an oil hub of some 1.3 million people , was underway by midday , with coalition troops trying to surround Iraqi positions and force a surrender .',
#    'tokens': ['The',
#     'battle',
#     'for',
#     'Basra',
#     ',',
#     'an',
#     'oil',
#     'hub',
#     'of',
#     'some',
#     '1.3',
#     'million',
#     'people',
#     ',',
#     'was',
#     'underway',
#     'by',
#     'midday',
#     ',',
#     'with',
#     'coalition',
#     'troops',
#     'trying',
#     'to',
#     'surround',
#     'Iraqi',
#     'positions',
#     'and',
#     'force',
#     'a',
#     'surrender',
#     '.']},
#   {'trigger text': 'bombed',
#    'trigger span': (2, 3),
#    'event type': 'Conflict:Attack',
#    'arguments': {'Attacker': [{'argument text': 'U.S.',
#       'argument span': (0, 1)}],
#     'Instrument': [{'argument text': 'aircraft', 'argument span': (1, 2)}],
#     'Place': [{'argument text': 'bridges', 'argument span': (6, 7)}]},
#    'passage': 'U.S. aircraft bombed Iraqi tanks holding bridges close to the city .',
#    'tokens': ['U.S.',
#     'aircraft',
#     'bombed',
#     'Iraqi',
#     'tanks',
#     'holding',
#     'bridges',
#     'close',
#     'to',
#     'the',
#     'city',
#     '.']},
#   {'trigger text': 'died',
#    'trigger span': (13, 14),
#    'event type': 'Life:Die',
#    'arguments': {},
#    'passage': 'Scott told police she did not tend to the baby , and it died after 30 minutes .',
#    'tokens': ['Scott',
#     'told',
#     'police',
#     'she',
#     'did',
#     'not',
#     'tend',
#     'to',
#     'the',
#     'baby',
#     ',',
#     'and',
#     'it',
#     'died',
#     'after',
#     '30',
#     'minutes',
#     '.']},
#   {'trigger text': 'die',
#    'trigger span': (6, 7),
#    'event type': 'Life:Die',
#    'arguments': {'Victim': [{'argument text': 'baby',
#       'argument span': (3, 4)}]},
#    'passage': 'She said the baby had to die , according to the criminal complaint .',
#    'tokens': ['She',
#     'said',
#     'the',
#     'baby',
#     'had',
#     'to',
#     'die',
#     ',',
#     'according',
#     'to',
#     'the',
#     'criminal',
#     'complaint',
#     '.']},
#   {'trigger text': 'moved',
#    'trigger span': (5, 6),
#    'event type': 'Movement:Transport',
#    'arguments': {'Artifact': [{'argument text': 'body',
#       'argument span': (7, 8)}],
#     'Destination': [{'argument text': 'closet', 'argument span': (18, 19)},
#      {'argument text': 'closet', 'argument span': (34, 35)}]},
#    'passage': 'Scott told investigators she had moved that body around before she moved to Texas , sometimes in the closet at the Byrds Creek house , in the trunk of her car and in the closet of her apartment in Richland Center , the complaint said .',
#    'tokens': ['Scott',
#     'told',
#     'investigators',
#     'she',
#     'had',
#     'moved',
#     'that',
#     'body',
#     'around',
#     'before',
#     'she',
#     'moved',
#     'to',
#     'Texas',
#     ',',
#     'sometimes',
#     'in',
#     'the',
#     'closet',
#     'at',
#     'the',
#     'Byrds',
#     'Creek',
#     'house',
#     ',',
#     'in',
#     'the',
#     'trunk',
#     'of',
#     'her',
#     'car',
#     'and',
#     'in',
#     'the',
#     'closet',
#     'of',
#     'her',
#     'apartment',
#     'in',
#     'Richland',
#     'Center',
#     ',',
#     'the',
#     'complaint',
#     'said',
#     '.']},
#   {'trigger text': 'moved',
#    'trigger span': (11, 12),
#    'event type': 'Movement:Transport',
#    'arguments': {'Destination': [{'argument text': 'Texas',
#       'argument span': (13, 14)}]},
#    'passage': 'Scott told investigators she had moved that body around before she moved to Texas , sometimes in the closet at the Byrds Creek house , in the trunk of her car and in the closet of her apartment in Richland Center , the complaint said .',
#    'tokens': ['Scott',
#     'told',
#     'investigators',
#     'she',
#     'had',
#     'moved',
#     'that',
#     'body',
#     'around',
#     'before',
#     'she',
#     'moved',
#     'to',
#     'Texas',
#     ',',
#     'sometimes',
#     'in',
#     'the',
#     'closet',
#     'at',
#     'the',
#     'Byrds',
#     'Creek',
#     'house',
#     ',',
#     'in',
#     'the',
#     'trunk',
#     'of',
#     'her',
#     'car',
#     'and',
#     'in',
#     'the',
#     'closet',
#     'of',
#     'her',
#     'apartment',
#     'in',
#     'Richland',
#     'Center',
#     ',',
#     'the',
#     'complaint',
#     'said',
#     '.']},
#   {'trigger text': 'divorce',
#    'trigger span': (7, 8),
#    'event type': 'Life:Divorce',
#    'arguments': {'Person': [{'argument text': 'Rachel Hunter',
#       'argument span': (1, 3)},
#      {'argument text': 'husband', 'argument span': (12, 13)}]},
#    'passage': 'Supermodel Rachel Hunter on Tuesday filed for divorce from her estranged rocker husband Rod Stewart , four years after the couple separated , court papers showed .',
#    'tokens': ['Supermodel',
#     'Rachel',
#     'Hunter',
#     'on',
#     'Tuesday',
#     'filed',
#     'for',
#     'divorce',
#     'from',
#     'her',
#     'estranged',
#     'rocker',
#     'husband',
#     'Rod',
#     'Stewart',
#     ',',
#     'four',
#     'years',
#     'after',
#     'the',
#     'couple',
#     'separated',
#     ',',
#     'court',
#     'papers',
#     'showed',
#     '.']},
#   {'trigger text': 'met',
#    'trigger span': (5, 6),
#    'event type': 'Contact:Meet',
#    'arguments': {'Entity': [{'argument text': 'Bremer',
#       'argument span': (7, 8)}]},
#    'passage': 'Officials from Iraqi groups that met with Bremer last week have said that he back peddled on what they said were earlier pledges to give them a lead role in forming a new interim government in the next few weeks .',
#    'tokens': ['Officials',
#     'from',
#     'Iraqi',
#     'groups',
#     'that',
#     'met',
#     'with',
#     'Bremer',
#     'last',
#     'week',
#     'have',
#     'said',
#     'that',
#     'he',
#     'back',
#     'peddled',
#     'on',
#     'what',
#     'they',
#     'said',
#     'were',
#     'earlier',
#     'pledges',
#     'to',
#     'give',
#     'them',
#     'a',
#     'lead',
#     'role',
#     'in',
#     'forming',
#     'a',
#     'new',
#     'interim',
#     'government',
#     'in',
#     'the',
#     'next',
#     'few',
#     'weeks',
#     '.']},
#   {'trigger text': 'elected',
#    'trigger span': (24, 25),
#    'event type': 'Personnel:Elect',
#    'arguments': {},
#    'passage': '" We understand that they want to have as much power as possible but we told them : \' You wo n\'t be directly elected , you wo n\'t have any direct experience of government , " the source said .',
#    'tokens': ['"',
#     'We',
#     'understand',
#     'that',
#     'they',
#     'want',
#     'to',
#     'have',
#     'as',
#     'much',
#     'power',
#     'as',
#     'possible',
#     'but',
#     'we',
#     'told',
#     'them',
#     ':',
#     "'",
#     'You',
#     'wo',
#     "n't",
#     'be',
#     'directly',
#     'elected',
#     ',',
#     'you',
#     'wo',
#     "n't",
#     'have',
#     'any',
#     'direct',
#     'experience',
#     'of',
#     'government',
#     ',',
#     '"',
#     'the',
#     'source',
#     'said',
#     '.']},
#   {'trigger text': 'elected',
#    'trigger span': (18, 19),
#    'event type': 'Personnel:Elect',
#    'arguments': {},
#    'passage': '" \' Of course you will have input into the government but , since you are not directly elected , it would be a nonsense for you to have direct executive power , \' the source said .',
#    'tokens': ['"',
#     "'",
#     'Of',
#     'course',
#     'you',
#     'will',
#     'have',
#     'input',
#     'into',
#     'the',
#     'government',
#     'but',
#     ',',
#     'since',
#     'you',
#     'are',
#     'not',
#     'directly',
#     'elected',
#     ',',
#     'it',
#     'would',
#     'be',
#     'a',
#     'nonsense',
#     'for',
#     'you',
#     'to',
#     'have',
#     'direct',
#     'executive',
#     'power',
#     ',',
#     "'",
#     'the',
#     'source',
#     'said',
#     '.']},
#   {'trigger text': 'elections',
#    'trigger span': (16, 17),
#    'event type': 'Personnel:Elect',
#    'arguments': {'Place': [{'argument text': 'Iraq',
#       'argument span': (18, 19)}]},
#    'passage': 'The comments came on the same day that a prominent Iraqi called for internationally - supervised elections in Iraq .',
#    'tokens': ['The',
#     'comments',
#     'came',
#     'on',
#     'the',
#     'same',
#     'day',
#     'that',
#     'a',
#     'prominent',
#     'Iraqi',
#     'called',
#     'for',
#     'internationally',
#     '-',
#     'supervised',
#     'elections',
#     'in',
#     'Iraq',
#     '.']},
#   {'trigger text': 'returned',
#    'trigger span': (8, 9),
#    'event type': 'Movement:Transport',
#    'arguments': {'Destination': [{'argument text': 'Iraq',
#       'argument span': (10, 11)}]},
#    'passage': 'Adnan Pachachi , a onetime foreign minister who returned to Iraq on May 6 after 33 years in exile , told the independent Az - Zaman daily that elections should be held under international supervision .',
#    'tokens': ['Adnan',
#     'Pachachi',
#     ',',
#     'a',
#     'onetime',
#     'foreign',
#     'minister',
#     'who',
#     'returned',
#     'to',
#     'Iraq',
#     'on',
#     'May',
#     '6',
#     'after',
#     '33',
#     'years',
#     'in',
#     'exile',
#     ',',
#     'told',
#     'the',
#     'independent',
#     'Az',
#     '-',
#     'Zaman',
#     'daily',
#     'that',
#     'elections',
#     'should',
#     'be',
#     'held',
#     'under',
#     'international',
#     'supervision',
#     '.']}]}
